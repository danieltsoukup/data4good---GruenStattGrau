# %% [markdown]
# # Location extraction and visualization

# %% [markdown]
# Our first goal is to see what locations appear in the text and look at their distribution. Let's start by loading all the necessary modules.

# %%
# generally useful packages
import re
import pprint
import glob, os, requests, io
import pickle
import collections

# for data management, visualization and math
import pandas as pd

import numpy as np
#import networkx as nx

import matplotlib.pyplot as plt
import seaborn as sns
import folium

# NLP packages, we work with German text so we load that
import nltk
import spacy
nlp = spacy.load("de_core_news_sm")

# for location detection
from geotext import GeoText

# %% [markdown]
# ## Building the corpus

# %% [markdown]
# Now we read the txt files and build our corpus.

# %%
data_path = "../data/interim/pdf2text"

data_files = glob.glob(data_path + os.path.sep + "*.txt"); data_files

data_files = [item.replace(data_path + os.path.sep, "") for item in data_files]  # Strip the dir name and the path separator from begining

corpus = []

for txt_file in data_files:
    with open(data_path + os.path.sep + txt_file, encoding='utf-8', mode="r") as f:
        corpus.append(f.readlines())

# %% [markdown]
# Let's see how many documents are loaded:

# %%
len(corpus)
# Out:
# 25

# %% [markdown]
# # Finding locations in the text (NER with Spacy)

# %% [markdown]
# Now, we use the Spacy's nlp pipeline to process the corpus. This includes tokenizing, tagging, parsing, identifying and labeling named entities (exactly what we want).

# %%
nlp_corpus = []
for idx, raw in enumerate(corpus):
    joined = ' '.join(raw) # we join the docs (which are lists of strings)
    joined_nlp = nlp(joined) 
    nlp_corpus.append(joined_nlp)

# %% [markdown]
# Now, let's find the sentences that include named entities labeled as LOC. As we go, we put the results into a dataframe.

# %%
sents_with_loc = pd.DataFrame({'doc number': [], 'location': [], 'sentence': []})

for idx, doc in enumerate(nlp_corpus):
    for sent in doc.sents:
        locations = []
        for ent in sent.as_doc().ents:
            if ent.label_ == "LOC":
                locations.append(ent.text)
        if locations:
            sents_with_loc.loc[len(sents_with_loc)] =[idx, locations, sent]

# %% [markdown]
# Let's see what we have.

# %%
sents_with_loc.head(10)
# Out:
#    doc number                                     location  \
# 0           0                         [Biodiversitätsdach]
# 1           0                    [Berlin, Pflanzenauswahl]
# 2           0                       [Biodiversitätsdächer]
# 3           0  [Biodiversitätsprinzipien, Biotop-Funktion]
# 4           0                    [Biodiversitäts-Gründach]
# 5           0                         [Biodiversitätsdach]
# 6           0                                 [Totholz\n ]
# 7           0                                    [Totholz]
# 8           0                         [Biodiversitätsdach]
# 9           0                           [www.tu-berlin.de]
#
#                                             sentence
# 0  (Biodiversitätsdach, auf, dem, Besucherzentrum...
# 1  (Dachbegrünung, und, Biodiversität, \n \n , 2,...
# 2  (Biodiversitätsdächer, \n \n , 16, \n \n , Koo...
# 3  (Durch, verschiedene, Gestaltungsmaßnahmen, un...
# 4  (Dem, Deutschen, Dachgärtner, Verband, dient, ...
# 5  (Ein, ,, ,, upgrade, ", bereits, existierender...
# 6      (10, \n \n
# , Einbringung, von, Totholz, \n )
# 7  (Totholz, wird, unter, anderem, von, Moosen, ,...
# 8  (Für, das, Biodiversitätsdach, wird, deshalb, ...
# 9  (www.dachgaertnerverband.de, \n \n , www.tu-be...

# %%
sents_with_loc.dtypes
# Out:
# doc number     int32
# location      object
# sentence      object
# dtype: object

# %% [markdown]
# It is clear that there are plenty of tokens that are actually not addresses we were looking for.

# %%
# make doc numbers an integer
sents_with_loc['doc number'] = sents_with_loc['doc number'].astype(int)
sents_with_loc['location'] = sents_with_loc['location'].astype(str)
sents_with_loc['sentence'] = sents_with_loc['sentence'].astype(str)

# number of sentences
len(sents_with_loc)
# Out:
# 7728

# %% [markdown]
# Save the dataframe.

# %%
sents_with_loc.to_pickle("sents_with_loc.pkl")

# %% [markdown]
# # Identifying coutries and cities (GeoText)

# %% [markdown]
# Now, let's catch the country and city mentions using GeoText. Here is a simple example how it works:

# %%
cdict = GeoText('New York, Texas, and also Warsaw').country_mentions
cdict
# Out:
# OrderedDict([('US', 2), ('PL', 1)])

# %% [markdown]
# The GeoText function is not flawless as illustrated here:

# %%
places = GeoText("Munchen")
places.country_mentions
# Out:
# OrderedDict()

# %% [markdown]
# For our text:

# %%
sents_with_loc = pd.read_pickle('sents_with_loc.pkl')
sents_with_loc['country mentions'] = pd.Series([GeoText(sent).country_mentions for sent in sents_with_loc['sentence']],
                                               index = sents_with_loc.index)

sents_with_loc['cities'] = pd.Series([GeoText(sent).cities for sent in sents_with_loc['sentence']],
                                               index = sents_with_loc.index)

# %%
sents_with_loc.head(10)
# Out:
#     doc number                                           location  \
# 0            0                             ['Biodiversitätsdach']
# 1            0                      ['Berlin', 'Pflanzenauswahl']
# 11           0                                     ['Schorndorf']
# 12           0                                      ['Falkensee']
# 16           1  ['Hamburg', 'Hannover', 'Berlin', 'Kornwestheim']
# 26           1  ['Berlin', 'Hamburg', 'Hannover', 'Ludwigsburg...
# 27           1                                       ['Hannover']
# 28           1                                      ['Stuttgart']
# 30           1                                         ['Berlin']
# 31           1                                    ['Ludwigsburg']
#
#                                              sentence country mentions  \
# 0   Biodiversitätsdach auf dem Besucherzentrum der...        {'DE': 1}
# 1   Dachbegrünung und Biodiversität\n \n 2\n \n Be...        {'DE': 1}
# 11  Ansprechpartner im Bereich der Nisthilfen war ...        {'DE': 1}
# 12  Für das Totholz zeichnete sich die Firma Kusch...        {'DE': 1}
# 16  (Deutscher Dachgärtner Verband e.V. - DDV), Ju...        {'DE': 5}
# 26  Neben aktuellen Gründach-Initiativen aus Berli...        {'DE': 5}
# 27                                  25\n \n Hannover:        {'DE': 1}
# 28  Gebäudebegrünung als Bestandteil der Klimaanpa...        {'DE': 1}
# 30                                    32\n \n Berlin:        {'DE': 1}
# 31  Ökologische Gebäudekonzepte und Modellvorhaben...        {'DE': 1}
#
#                                                cities
# 0                                            [Berlin]
# 1                                            [Berlin]
# 11                                       [Schorndorf]
# 12                                        [Falkensee]
# 16  [Hamburg, Stuttgart, Hannover, Berlin, Kornwes...
# 26  [Berlin, Hamburg, Hannover, Ludwigsburg, Stutt...
# 27                                         [Hannover]
# 28                                        [Stuttgart]
# 30                                           [Berlin]
# 31                                      [Ludwigsburg]

# %% [markdown]
# In any case, let's discard the rows without any location detected for now:

# %%
sents_with_loc = sents_with_loc[sents_with_loc['country mentions'] != {}]
sents_with_loc.head()
# Out:
#     doc number                                           location  \
# 0            0                             ['Biodiversitätsdach']
# 1            0                      ['Berlin', 'Pflanzenauswahl']
# 11           0                                     ['Schorndorf']
# 12           0                                      ['Falkensee']
# 16           1  ['Hamburg', 'Hannover', 'Berlin', 'Kornwestheim']
#
#                                              sentence country mentions  \
# 0   Biodiversitätsdach auf dem Besucherzentrum der...        {'DE': 1}
# 1   Dachbegrünung und Biodiversität\n \n 2\n \n Be...        {'DE': 1}
# 11  Ansprechpartner im Bereich der Nisthilfen war ...        {'DE': 1}
# 12  Für das Totholz zeichnete sich die Firma Kusch...        {'DE': 1}
# 16  (Deutscher Dachgärtner Verband e.V. - DDV), Ju...        {'DE': 5}
#
#                                                cities
# 0                                            [Berlin]
# 1                                            [Berlin]
# 11                                       [Schorndorf]
# 12                                        [Falkensee]
# 16  [Hamburg, Stuttgart, Hannover, Berlin, Kornwes...

# %% [markdown]
# We can do a save here:

# %%
sents_with_loc.to_pickle('sents_with_loc.pkl')

# %% [markdown]
# ## Counting cities and countries

# %% [markdown]
# Next, we'll count each country and city occurence.

# %%
sents_with_loc = pd.read_pickle('sents_with_loc.pkl')
len(sents_with_loc)
# Out:
# 1362

# %%
sents_with_loc.head()
# Out:
#     doc number                                           location  \
# 0            0                             ['Biodiversitätsdach']
# 1            0                      ['Berlin', 'Pflanzenauswahl']
# 11           0                                     ['Schorndorf']
# 12           0                                      ['Falkensee']
# 16           1  ['Hamburg', 'Hannover', 'Berlin', 'Kornwestheim']
#
#                                              sentence country mentions  \
# 0   Biodiversitätsdach auf dem Besucherzentrum der...        {'DE': 1}
# 1   Dachbegrünung und Biodiversität\n \n 2\n \n Be...        {'DE': 1}
# 11  Ansprechpartner im Bereich der Nisthilfen war ...        {'DE': 1}
# 12  Für das Totholz zeichnete sich die Firma Kusch...        {'DE': 1}
# 16  (Deutscher Dachgärtner Verband e.V. - DDV), Ju...        {'DE': 5}
#
#                                                cities
# 0                                            [Berlin]
# 1                                            [Berlin]
# 11                                       [Schorndorf]
# 12                                        [Falkensee]
# 16  [Hamburg, Stuttgart, Hannover, Berlin, Kornwes...

# %%
country_count = collections.defaultdict(int)

for index, row in sents_with_loc.iterrows():
    #countries
    
    for code, value in  row['country mentions'].items():
        country_count[code] += value 

country_count
# Out:
# defaultdict(int,
#             {'DE': 1290,
#              'CI': 3,
#              'SE': 23,
#              'FR': 50,
#              'US': 124,
#              'ID': 6,
#              'KZ': 1,
#              'CN': 18,
#              'GB': 21,
#              'UZ': 1,
#              'KW': 12,
#              'CA': 7,
#              'NO': 4,
#              'AU': 6,
#              'MY': 1,
#              'SG': 8,
#              'BE': 2,
#              'IL': 18,
#              'PT': 15,
#              'TW': 1,
#              'CH': 27,
#              'NL': 12,
#              'ZA': 4,
#              'AT': 25,
#              'IT': 5,
#              'RU': 4,
#              'JP': 7,
#              'NP': 1,
#              'ES': 9,
#              'PH': 3,
#              'HU': 10,
#              'IN': 5,
#              'SK': 1,
#              'AR': 1,
#              'SZ': 1,
#              'KR': 5,
#              'MX': 7,
#              'IR': 4,
#              'VE': 1,
#              'CL': 2,
#              'MR': 1,
#              'BG': 2,
#              'TR': 1,
#              'HK': 12,
#              'DK': 1,
#              'BR': 1,
#              'PL': 1})

# %%
city_count = collections.defaultdict(int)

for index, row in sents_with_loc.iterrows():
    #cities
    for city in row['cities']:
        city_count[city] += 1
    
city_count
# Out:
# defaultdict(int,
#             {'Berlin': 395,
#              'Schorndorf': 3,
#              'Falkensee': 3,
#              'Hamburg': 93,
#              'Stuttgart': 144,
#              'Hannover': 44,
#              'Kornwestheim': 12,
#              'Ludwigsburg': 9,
#              'Karlsruhe': 13,
#              'Man': 3,
#              'Boden': 20,
#              'Adlershof': 4,
#              'Mannheim': 20,
#              'Bonn': 19,
#              'Köln': 37,
#              'Bad Honnef': 6,
#              'Bochum': 5,
#              'Darmstadt': 16,
#              'Rostock': 1,
#              'Bremen': 15,
#              'Auch': 37,
#              'Lage': 16,
#              'Wiesbaden': 5,
#              'Kassel': 7,
#              'Chicago': 9,
#              'Konstanz': 1,
#              'Magdeburg': 2,
#              'Ende': 6,
#              'Neustadt': 1,
#              'Solon': 1,
#              'Aral': 1,
#              'Bad Hersfeld': 1,
#              'Leipzig': 22,
#              'Ingolstadt': 10,
#              'Sheffield': 3,
#              'Essen': 24,
#              'Pop': 1,
#              'Waiblingen': 1,
#              'Aachen': 9,
#              'Reutlingen': 6,
#              'San Francisco': 7,
#              'Kuwait City': 4,
#              'Hellersdorf': 1,
#              'Sydney': 4,
#              'Oslo': 2,
#              'Dortmund': 7,
#              'Forster': 4,
#              'Baden-Baden': 1,
#              'Menlo Park': 5,
#              'Heiligenhaus': 4,
#              'Johnson': 1,
#              'Eutin': 2,
#              'Ditzingen': 50,
#              'New York': 6,
#              'Rotterdam': 7,
#              'Pfullingen': 1,
#              'Norderstedt': 1,
#              'Boom': 1,
#              'Jerusalem': 9,
#              'Porto': 10,
#              'Erfurt': 3,
#              'Basel': 9,
#              'Paris': 12,
#              'Baltimore': 2,
#              'Malmö': 3,
#              'Leeuwarden': 2,
#              'Amsterdam': 15,
#              'Westerstede': 2,
#              'Mitte': 9,
#              'Dresden': 23,
#              'Freising': 2,
#              'Rastatt': 1,
#              'Neuss': 6,
#              'Germering': 1,
#              'Wuppertal': 5,
#              'Weimar': 2,
#              'Saarlouis': 2,
#              'Lindau': 1,
#              'Ratingen': 1,
#              'Braunschweig': 4,
#              'Heidelberg': 2,
#              'Graz': 9,
#              'Salzburg': 2,
#              'Feldkirch': 5,
#              'Colchester': 1,
#              'Arlington': 1,
#              'Virginia': 1,
#              'Hohen Neuendorf': 1,
#              'Horst': 1,
#              'Adler': 1,
#              'Madrid': 7,
#              'Genève': 2,
#              'Lausanne': 4,
#              'Linz': 4,
#              'Veenendaal': 2,
#              'BAy': 2,
#              'Pforzheim': 1,
#              'Dormagen': 5,
#              'Kaarst': 1,
#              'Oldenburg': 3,
#              'Worms': 2,
#              'Trondheim': 1,
#              'Laupheim': 1,
#              'Halle': 19,
#              'Innsbruck': 3,
#              'Budapest': 8,
#              'Wer': 2,
#              'Norden': 3,
#              'Regensburg': 1,
#              'Hof': 2,
#              'Gelsenkirchen': 5,
#              'Martin': 1,
#              'Westend': 1,
#              'Vera': 1,
#              'Potsdam': 1,
#              'Green': 11,
#              'Schöneberg': 2,
#              'Bad Laasphe': 3,
#              'Augsburg': 4,
#              'Jena': 1,
#              'Krefeld': 5,
#              'Keller': 1,
#              'Lennestadt': 1,
#              'La Rochelle': 7,
#              'Trier': 3,
#              'Amstetten': 1,
#              'Utrecht': 1,
#              'Duisburg': 1,
#              'Wedel': 2,
#              'Marktoberdorf': 1,
#              'Bad Bentheim': 1,
#              'London': 18,
#              'Newton': 1,
#              'Delfshaven': 1,
#              'Kerkrade': 1,
#              'Wetzlar': 1,
#              'Anna': 1,
#              'Bologna': 2,
#              'Seattle': 2,
#              'Seoul': 4,
#              'Bangalore': 3,
#              'Neubrandenburg': 10,
#              'Korntal': 6,
#              'Schwäbisch Hall': 1,
#              'Ufa': 2,
#              'Baden': 3,
#              'Marseille': 1,
#              'University': 5,
#              'Portland': 2,
#              'Bernburg': 1,
#              'Holland': 3,
#              'Nantes': 1,
#              'Hangzhou': 1,
#              'Nanjing': 2,
#              'Mexico City': 4,
#              'Shiraz': 2,
#              'Barcelona': 1,
#              'Leinfelden-Echterdingen': 2,
#              'Arnold': 3,
#              'Remscheid': 4,
#              'Irvine': 1,
#              'Evans': 3,
#              'Davis': 2,
#              'Chemnitz': 3,
#              'Cottbus': 2,
#              'Bergisch Gladbach': 2,
#              'Delft': 2,
#              'Achim': 5,
#              'Lohne': 3,
#              'Bergheim': 4,
#              'Herdecke': 2,
#              'Emmerich': 4,
#              'Mechernich': 3,
#              'Ostfildern': 4,
#              'Montpellier': 1,
#              'Esslingen': 4,
#              'Frechen': 3,
#              'Lahr': 4,
#              'Bad Pyrmont': 8,
#              'Lahnstein': 2,
#              'Dillingen': 3,
#              'Offenbach': 2,
#              'Rosso': 1,
#              'Muttenz': 1,
#              'Holzkirchen': 3,
#              'Kiel': 1,
#              'Unna': 1,
#              'Dublin': 1,
#              'Sofia': 1,
#              'East London': 1,
#              'Bay': 1,
#              'Speyer': 2,
#              'Mut': 1,
#              'Plauen': 2,
#              'Viernheim': 7,
#              'Bietigheim-Bissingen': 8,
#              'Werne': 3,
#              'Bamberg': 4,
#              'Steinhagen': 1,
#              'Andernach': 5,
#              'Laatzen': 1,
#              'Rodgau': 2,
#              'Thun': 2,
#              'Freiburg': 4,
#              'Kreuzberg': 1,
#              'Hildesheim': 1,
#              'Pankow': 1,
#              'Gunzenhausen': 1,
#              'Rome': 1,
#              'Oberhausen': 1,
#              'Shanghai': 3,
#              'Vellmar': 2,
#              'Leverkusen': 1,
#              'Hilden': 2,
#              'Bern': 1,
#              'Vienna': 9,
#              'Emmen': 1,
#              'Copenhagen': 1,
#              'Washington': 1,
#              'Munich': 1,
#              'Hanover': 1,
#              'Lisbon': 2,
#              'Toronto': 2,
#              'Ardea': 1,
#              'Melbourne': 2,
#              'Los Angeles': 2,
#              'Zaragoza': 1,
#              'Oxford': 1,
#              'Foster': 1,
#              'Houten': 1,
#              'Palo Alto': 1,
#              'Denver': 2,
#              'Colorado': 1,
#              'Bolzano': 1,
#              'Boston': 1,
#              'Aue': 1})

# %% [markdown]
# Which countries were mentioned the most?

# %%
country_data = pd.DataFrame({
   'country code':[code for code in country_count.keys()],
    'freq':[country_count[code] for code in country_count.keys()]})

country_data = country_data.sort_values(by = 'freq', ascending = False)
country_data.head(10)
# Out:
#    country code  freq
# 0            DE  1290
# 4            US   124
# 3            FR    50
# 20           CH    27
# 23           AT    25
# 2            SE    23
# 8            GB    21
# 7            CN    18
# 17           IL    18
# 18           PT    15

# %% [markdown]
# Ommiting Germany, we have the following barchart:

# %%
sns.set_color_codes("pastel")


f, ax = plt.subplots(figsize=(14, 8))
sns.barplot(x = 'country code', y = 'freq', data = country_data[1:10], color = 'b')

ax.set( ylabel="Number of mentions",
         xlabel="Highest mentioned countries after Germany")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Visualization on maps

# %% [markdown]
# Let's visualize this! We get coordinates for the countries first:

# %%
url = 'https://developers.google.com/public-data/docs/canonical/countries_csv'
html = requests.get(url).content
df_coords = pd.read_html(html)
df_coords = df_coords[0]
df_coords.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %% [markdown]
# We use folium to put markers proportional to the frequencies:

# %%
 # Make an empty map
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
data = country_data

# we add markers one by one to the map
for i in range(1,20):
    code = data.iloc[i]['country code']
    lon = int(df_coords[df_coords['country'] == code]['longitude'])
    lat = int(df_coords[df_coords['country'] == code]['latitude'])
    folium.Circle(
      location=[lat, lon],
      popup = code + ': ' + str(data.iloc[i]['freq']) + ' mentions', # pop-up label above marker
      radius = int(data.iloc[i]['freq']) * 10000,
      color = 'crimson',
      fill = True,
      fill_color = 'crimson'
   ).add_to(m)

m.save('world_mentions.png')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
city_count
# Out:
# defaultdict(int,
#             {'Berlin': 395,
#              'Schorndorf': 3,
#              'Falkensee': 3,
#              'Hamburg': 93,
#              'Stuttgart': 144,
#              'Hannover': 44,
#              'Kornwestheim': 12,
#              'Ludwigsburg': 9,
#              'Karlsruhe': 13,
#              'Man': 3,
#              'Boden': 20,
#              'Adlershof': 4,
#              'Mannheim': 20,
#              'Bonn': 19,
#              'Köln': 37,
#              'Bad Honnef': 6,
#              'Bochum': 5,
#              'Darmstadt': 16,
#              'Rostock': 1,
#              'Bremen': 15,
#              'Auch': 37,
#              'Lage': 16,
#              'Wiesbaden': 5,
#              'Kassel': 7,
#              'Chicago': 9,
#              'Konstanz': 1,
#              'Magdeburg': 2,
#              'Ende': 6,
#              'Neustadt': 1,
#              'Solon': 1,
#              'Aral': 1,
#              'Bad Hersfeld': 1,
#              'Leipzig': 22,
#              'Ingolstadt': 10,
#              'Sheffield': 3,
#              'Essen': 24,
#              'Pop': 1,
#              'Waiblingen': 1,
#              'Aachen': 9,
#              'Reutlingen': 6,
#              'San Francisco': 7,
#              'Kuwait City': 4,
#              'Hellersdorf': 1,
#              'Sydney': 4,
#              'Oslo': 2,
#              'Dortmund': 7,
#              'Forster': 4,
#              'Baden-Baden': 1,
#              'Menlo Park': 5,
#              'Heiligenhaus': 4,
#              'Johnson': 1,
#              'Eutin': 2,
#              'Ditzingen': 50,
#              'New York': 6,
#              'Rotterdam': 7,
#              'Pfullingen': 1,
#              'Norderstedt': 1,
#              'Boom': 1,
#              'Jerusalem': 9,
#              'Porto': 10,
#              'Erfurt': 3,
#              'Basel': 9,
#              'Paris': 12,
#              'Baltimore': 2,
#              'Malmö': 3,
#              'Leeuwarden': 2,
#              'Amsterdam': 15,
#              'Westerstede': 2,
#              'Mitte': 9,
#              'Dresden': 23,
#              'Freising': 2,
#              'Rastatt': 1,
#              'Neuss': 6,
#              'Germering': 1,
#              'Wuppertal': 5,
#              'Weimar': 2,
#              'Saarlouis': 2,
#              'Lindau': 1,
#              'Ratingen': 1,
#              'Braunschweig': 4,
#              'Heidelberg': 2,
#              'Graz': 9,
#              'Salzburg': 2,
#              'Feldkirch': 5,
#              'Colchester': 1,
#              'Arlington': 1,
#              'Virginia': 1,
#              'Hohen Neuendorf': 1,
#              'Horst': 1,
#              'Adler': 1,
#              'Madrid': 7,
#              'Genève': 2,
#              'Lausanne': 4,
#              'Linz': 4,
#              'Veenendaal': 2,
#              'BAy': 2,
#              'Pforzheim': 1,
#              'Dormagen': 5,
#              'Kaarst': 1,
#              'Oldenburg': 3,
#              'Worms': 2,
#              'Trondheim': 1,
#              'Laupheim': 1,
#              'Halle': 19,
#              'Innsbruck': 3,
#              'Budapest': 8,
#              'Wer': 2,
#              'Norden': 3,
#              'Regensburg': 1,
#              'Hof': 2,
#              'Gelsenkirchen': 5,
#              'Martin': 1,
#              'Westend': 1,
#              'Vera': 1,
#              'Potsdam': 1,
#              'Green': 11,
#              'Schöneberg': 2,
#              'Bad Laasphe': 3,
#              'Augsburg': 4,
#              'Jena': 1,
#              'Krefeld': 5,
#              'Keller': 1,
#              'Lennestadt': 1,
#              'La Rochelle': 7,
#              'Trier': 3,
#              'Amstetten': 1,
#              'Utrecht': 1,
#              'Duisburg': 1,
#              'Wedel': 2,
#              'Marktoberdorf': 1,
#              'Bad Bentheim': 1,
#              'London': 18,
#              'Newton': 1,
#              'Delfshaven': 1,
#              'Kerkrade': 1,
#              'Wetzlar': 1,
#              'Anna': 1,
#              'Bologna': 2,
#              'Seattle': 2,
#              'Seoul': 4,
#              'Bangalore': 3,
#              'Neubrandenburg': 10,
#              'Korntal': 6,
#              'Schwäbisch Hall': 1,
#              'Ufa': 2,
#              'Baden': 3,
#              'Marseille': 1,
#              'University': 5,
#              'Portland': 2,
#              'Bernburg': 1,
#              'Holland': 3,
#              'Nantes': 1,
#              'Hangzhou': 1,
#              'Nanjing': 2,
#              'Mexico City': 4,
#              'Shiraz': 2,
#              'Barcelona': 1,
#              'Leinfelden-Echterdingen': 2,
#              'Arnold': 3,
#              'Remscheid': 4,
#              'Irvine': 1,
#              'Evans': 3,
#              'Davis': 2,
#              'Chemnitz': 3,
#              'Cottbus': 2,
#              'Bergisch Gladbach': 2,
#              'Delft': 2,
#              'Achim': 5,
#              'Lohne': 3,
#              'Bergheim': 4,
#              'Herdecke': 2,
#              'Emmerich': 4,
#              'Mechernich': 3,
#              'Ostfildern': 4,
#              'Montpellier': 1,
#              'Esslingen': 4,
#              'Frechen': 3,
#              'Lahr': 4,
#              'Bad Pyrmont': 8,
#              'Lahnstein': 2,
#              'Dillingen': 3,
#              'Offenbach': 2,
#              'Rosso': 1,
#              'Muttenz': 1,
#              'Holzkirchen': 3,
#              'Kiel': 1,
#              'Unna': 1,
#              'Dublin': 1,
#              'Sofia': 1,
#              'East London': 1,
#              'Bay': 1,
#              'Speyer': 2,
#              'Mut': 1,
#              'Plauen': 2,
#              'Viernheim': 7,
#              'Bietigheim-Bissingen': 8,
#              'Werne': 3,
#              'Bamberg': 4,
#              'Steinhagen': 1,
#              'Andernach': 5,
#              'Laatzen': 1,
#              'Rodgau': 2,
#              'Thun': 2,
#              'Freiburg': 4,
#              'Kreuzberg': 1,
#              'Hildesheim': 1,
#              'Pankow': 1,
#              'Gunzenhausen': 1,
#              'Rome': 1,
#              'Oberhausen': 1,
#              'Shanghai': 3,
#              'Vellmar': 2,
#              'Leverkusen': 1,
#              'Hilden': 2,
#              'Bern': 1,
#              'Vienna': 9,
#              'Emmen': 1,
#              'Copenhagen': 1,
#              'Washington': 1,
#              'Munich': 1,
#              'Hanover': 1,
#              'Lisbon': 2,
#              'Toronto': 2,
#              'Ardea': 1,
#              'Melbourne': 2,
#              'Los Angeles': 2,
#              'Zaragoza': 1,
#              'Oxford': 1,
#              'Foster': 1,
#              'Houten': 1,
#              'Palo Alto': 1,
#              'Denver': 2,
#              'Colorado': 1,
#              'Bolzano': 1,
#              'Boston': 1,
#              'Aue': 1})

# %% [markdown]
# ## Cities from Germany

# %% [markdown]
# Let's look at Germany now and focus on the cities, simply counting first:

# %%
city_count_german = collections.defaultdict(int)
for city, count in city_count.items():
    place = GeoText(city)
    if 'DE' in place.country_mentions:
        city_count_german[city] += count

from operator import itemgetter 
city_count_german_sorted = sorted(city_count_german.items(), key = itemgetter(1), reverse = True)
city_count_german_sorted[:10]
# Out:
# [('Berlin', 395),
#  ('Stuttgart', 144),
#  ('Hamburg', 93),
#  ('Ditzingen', 50),
#  ('Hannover', 44),
#  ('Köln', 37),
#  ('Essen', 24),
#  ('Dresden', 23),
#  ('Leipzig', 22),
#  ('Mannheim', 20)]

# %% [markdown]
# The barchart now looks as follows:

# %%
data = pd.DataFrame({
   'country code':[pair[0] for pair in city_count_german_sorted],
    'freq':[pair[1] for pair in city_count_german_sorted]})

f, ax = plt.subplots(figsize=(15, 9))

sns.set_color_codes("pastel")
sns.barplot(y=data.loc[0:10,"freq"], x=data.loc[0:10,"country code"], 
            label="Number of mentions", color="b")

# legend
#ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set( ylabel="Number of mentions",
        xlabel="Highest mentioned cities in Germany")
sns.despine(left=True, bottom=True)

# %% [markdown]
# To map these as well, we get a map for the cities:

# %%
df_cities = pd.read_csv('../assets/worldcities.csv')
german_cities = df_cities[df_cities['country'] == 'Germany']
german_cities.head()
# Out:
#          city city_ascii      lat      lng  country iso2 iso3  \
# 6279   Berlin     Berlin  52.5218  13.4015  Germany   DE  DEU
# 6280  Cologne    Cologne  50.9300   6.9500  Germany   DE  DEU
# 6281   Munich     Munich  48.1299  11.5750  Germany   DE  DEU
# 6282  Potsdam    Potsdam  52.4004  13.0700  Germany   DE  DEU
# 6283     Kiel       Kiel  54.3304  10.1300  Germany   DE  DEU
#
#                   admin_name  capital  population          id
# 6279                  Berlin  primary   3406000.0  1276451290
# 6280  North Rhine-Westphalia      NaN   1004000.0  1276015998
# 6281                 Bavaria    admin   1275000.0  1276692352
# 6282             Brandenburg    admin    218095.0  1276395100
# 6283      Schleswig-Holstein    admin    269427.0  1276305306

# %% [markdown]
# The map now looks like this:

# %%
city_list = list()
not_found = list()

m2 = folium.Map(location=[51,10], tiles="Mapbox Bright", zoom_start=6)
 
    
for city, count in city_count.items():
    city_info = german_cities[german_cities['city'] == city]
    if count > 0 and len(city_info) > 0:
        city_list.append(city)
        #mask = german_cities['city'] == city
        lat = float(city_info['lat'])
        lon = float(city_info['lng'])

        folium.Circle(
        location=[lat, lon],
        popup = city + ':' + str(count) + ' mentions',
        radius = count * 150,
        color = 'crimson',
        fill = True,
        fill_color = 'crimson'
        ).add_to(m2)
    if len(city_info) == 0:
        not_found.append((city, count))
m2.save('germany_counts.html')

#print(not_found)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Green corridors - future project proposal

# %% [markdown]
# In the future, it would be nice to map green areas in a city and estimate the price of achieving large, connected green areas or so-called green corridors. This would involve:
# <ul>
#     <li>satellite image processing,  </li>
#         <li>creating schematic graph of the city marking green and non-green areas; </li>
#             <li> estimating the cost of making a unit green;  </li>
#                 <li> finding minimal weight connected subgraphs that contain a given set of green areas. </li>
# </ul>
#
# The most relevant references:
# <ul>
#     <li> Conrad, Jon M., et al. "Wildlife corridors as a connected subgraph problem." Journal of Environmental Economics and Management 63.1 (2012): 1-18.
#         </li>
#     <li> El-Kebir, Mohammed, and Gunnar W. Klau. "Solving the maximum-weight connected subgraph problem to optimality." arXiv preprint arXiv:1409.5308 (2014).
#         </li>
#   <ul>

# %% [markdown]
# ## Classifying location mentions

# %%
sents_with_loc = pd.read_pickle('sents_with_loc.pkl')

# %%
sents_with_loc.reset_index(inplace=True)
sents_with_loc.head()
# Out:
#    index  doc number                                           location  \
# 0      0           0                             ['Biodiversitätsdach']
# 1      1           0                      ['Berlin', 'Pflanzenauswahl']
# 2     11           0                                     ['Schorndorf']
# 3     12           0                                      ['Falkensee']
# 4     16           1  ['Hamburg', 'Hannover', 'Berlin', 'Kornwestheim']
#
#                                             sentence country mentions  \
# 0  Biodiversitätsdach auf dem Besucherzentrum der...        {'DE': 1}
# 1  Dachbegrünung und Biodiversität\n \n 2\n \n Be...        {'DE': 1}
# 2  Ansprechpartner im Bereich der Nisthilfen war ...        {'DE': 1}
# 3  Für das Totholz zeichnete sich die Firma Kusch...        {'DE': 1}
# 4  (Deutscher Dachgärtner Verband e.V. - DDV), Ju...        {'DE': 5}
#
#                                               cities
# 0                                           [Berlin]
# 1                                           [Berlin]
# 2                                       [Schorndorf]
# 3                                        [Falkensee]
# 4  [Hamburg, Stuttgart, Hannover, Berlin, Kornwes...

# %%
for sent in sents_with_loc.loc[:10, 'sentence']:
    print(sent)
    print('-' * 100)
# Out:
# Biodiversitätsdach auf dem Besucherzentrum der IGA Berlin 2017
#
# ----------------------------------------------------------------------------------------------------
# Dachbegrünung und Biodiversität
#
#  2
#
#  Besucherzentrum IGA Berlin 2017
#
#  4
#
#  Biodiversitätsmodule
#
#  6
#
#  Pflanzenauswahl
#
#  12
#
#  Pflege und Monitoring
#
#  14
#
#  Planung
# ----------------------------------------------------------------------------------------------------
# Ansprechpartner im Bereich der Nisthilfen war die Firma Schwegler Vogelund Naturschutzprodukte GmbH aus Schorndorf.
# ----------------------------------------------------------------------------------------------------
# Für das Totholz zeichnete sich die Firma Kusche und Dremel GmbH Baumdienst aus Falkensee verantwortlich.
# ----------------------------------------------------------------------------------------------------
# (Deutscher Dachgärtner Verband e.V. - DDV), Julian Zeidler (Deutsches Zentrum für Luft- und Raumfahrt - DLR), Dr. Thomas Esch (Deutsches Zentrum für Luft- und Raumfahrt - DLR), Dr. Hanna Bornholdt (Behörde für Umwelt und Energie ­ BUE, Hamburg), Alexander Schmid (Amt für Stadtplanung und Stadterneuerung, Stuttgart), Helmut Wahle (Fachbereich Umwelt und Stadtgrün, Hannover), Brigitte Reichmann (Senatsverwaltung für Stadtentwicklung und Umwelt, Berlin), Hans Müller (Helix Pflanzensysteme GmbH, Kornwestheim), Dr. Bernd Eisenberg (Universität Stuttgart), Dr.-Ing.
# ----------------------------------------------------------------------------------------------------
# Neben aktuellen Gründach-Initiativen aus Berlin, Hamburg, Hannover, Ludwigsburg und Stuttgart stellen wir Ihnen dabei auch das spannende Forschungsprojekt ,,Inventarisierung und Potenzialanalyse von Dachbegrünung" vor.
# ----------------------------------------------------------------------------------------------------
# 25
#
#  Hannover:
# ----------------------------------------------------------------------------------------------------
# Gebäudebegrünung als Bestandteil der Klimaanpassungsstrategie
#
#  28
#
#  Stuttgart:
# ----------------------------------------------------------------------------------------------------
# 32
#
#  Berlin:
# ----------------------------------------------------------------------------------------------------
# Ökologische Gebäudekonzepte und Modellvorhaben
#
#  36
#
#  Ludwigsburg:
# ----------------------------------------------------------------------------------------------------
# Die in dieser Broschüre vorgestellten praktischen Beispiele aus Berlin, Hamburg, Hannover, Ludwigsburg und Stuttgart zeigen, wie vielfältig das Instrumentarium der Handlungsfelder "Fordern, Fördern, Informieren" ist, aus dem sich die Kommunen bedienen können.
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### First approach: topic modelling

# %%
import gensim
from sklearn.feature_extraction.text import CountVectorizer


with open("stopwords-de.txt", encoding='utf-8', mode="r") as f:
        stopwords_de = f.read().splitlines()
stopwords_de = frozenset(stopwords_de)

# %%
vect = CountVectorizer(min_df=20, max_df=0.2, stop_words=stopwords_de, 
                       token_pattern='(?u)\\b\\w\\w\\w+\\b')

# our corpus
corpus = [sent for sent in sents_with_loc['sentence']]

# create the sparse matrix
X = vect.fit_transform(corpus)
# Out:
# D:\anaconda\envs\data4good\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['wahr'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
X
# Out:
# <1362x54 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2034 stored elements in Compressed Sparse Row format>

# %%
# IDs to words dict
id_map = dict((v, k) for k, v in vect.vocabulary_.items())

# Convert sparse matrix to gensim corpus.
corpus = gensim.matutils.Sparse2Corpus(X, documents_columns=False)


# Train the LDA model
from gensim.models.ldamodel import LdaModel

ldamodel = LdaModel(corpus=corpus,
               id2word=id_map,
               num_topics=10,
               passes=10,
                   random_state = 42)

# %% [markdown]
# If we check the topics, nothing stands out as super irrelevant (one of our topics is actually in English so some English text must have mixed in). Topic 1 might worth attention as it seems to consider html addresses.

# %%
ldamodel.print_topics(10)
# Out:
# [(0,
#   '0.477*"hannover" + 0.227*"usa" + 0.084*"mannheim" + 0.062*"stadt" + 0.022*"stuttgart" + 0.022*"leipzig" + 0.021*"dach" + 0.021*"münchen" + 0.005*"www" + 0.004*"and"'),
#  (1,
#   '0.498*"www" + 0.238*"stuttgart" + 0.098*"com" + 0.044*"prof" + 0.028*"essen" + 0.021*"bad" + 0.018*"mannheim" + 0.015*"gmbh" + 0.006*"köln" + 0.006*"dresden"'),
#  (2,
#   '0.305*"the" + 0.215*"green" + 0.136*"and" + 0.071*"roof" + 0.070*"roofs" + 0.048*"city" + 0.048*"urban" + 0.045*"for" + 0.034*"london" + 0.004*"gebäudebegrünung"'),
#  (3,
#   '0.319*"2017" + 0.200*"gründach" + 0.155*"stadt" + 0.083*"dachbegrünungen" + 0.069*"bad" + 0.050*"internationalen" + 0.029*"stuttgart" + 0.022*"gebäudebegrünung" + 0.022*"essen" + 0.007*"boden"'),
#  (4,
#   '0.457*"hamburg" + 0.109*"ddv" + 0.102*"gründach" + 0.084*"grün" + 0.046*"dachbegrünung" + 0.041*"2013" + 0.034*"internationalen" + 0.030*"stuttgart" + 0.025*"stadt" + 0.014*"mannheim"'),
#  (5,
#   '0.229*"köln" + 0.201*"bugg" + 0.168*"gebäude" + 0.143*"dresden" + 0.102*"2013" + 0.068*"stuttgart" + 0.023*"universität" + 0.009*"gebäudegrün" + 0.007*"dächer" + 0.005*"stadt"'),
#  (6,
#   '0.256*"gmbh" + 0.205*"fbb" + 0.125*"ditzingen" + 0.089*"2016" + 0.078*"gründachsymposium" + 0.057*"gebäudebegrünung" + 0.031*"leipzig" + 0.026*"gründach" + 0.021*"stuttgart" + 0.018*"2014"'),
#  (7,
#   '0.228*"2018" + 0.148*"universität" + 0.129*"umwelt" + 0.128*"institut" + 0.069*"gmbh" + 0.049*"2014" + 0.047*"hamburg" + 0.045*"stuttgart" + 0.034*"bugg" + 0.032*"prof"'),
#  (8,
#   '0.179*"dachbegrünung" + 0.175*"city" + 0.172*"deutschland" + 0.132*"dächer" + 0.082*"for" + 0.068*"london" + 0.041*"dachbegrünungen" + 0.036*"fassadenbegrünung" + 0.028*"urban" + 0.013*"mannheim"'),
#  (9,
#   '0.147*"gebäudegrün" + 0.122*"dach" + 0.100*"fassadenbegrünung" + 0.083*"frankfurt" + 0.080*"begrünung" + 0.073*"boden" + 0.065*"stuttgart" + 0.055*"münchen" + 0.047*"2017" + 0.044*"dachbegrünung"')]

# %%
# import pyLDAvis
# import pyLDAvis.gensim

# pyLDAvis.enable_notebook()


# vis_topics = pyLDAvis.gensim.prepare(ldamodel, corpus, id_map) 
# vis_topics

# %%
def topic_distribution(new_doc_list):
    new_transformed = vect.transform(new_doc_list)
    new_corpus = gensim.matutils.Sparse2Corpus(new_transformed, documents_columns=False) 
    return ldamodel[new_corpus[0]]

def dominant_topic(new_doc_list):
    topics = topic_distribution(new_doc_list)
    topics.sort(key = lambda x: x[1], reverse=True)
    return topics[0]

sents_with_loc['dominant topic'] = pd.Series([dominant_topic([sent]) 
                                              for sent in sents_with_loc['sentence']])

# %%
def filter_for_topic(df, top_id):
    filtered_df = df[[topic[0] == top_id for topic in df['dominant topic']]]
    return filtered_df[['sentence', 'dominant topic']]

filter_for_topic(sents_with_loc, 1)
# Out:
#                                                sentence   dominant topic
# 24                                           Stuttgart:  (1, 0.54997414)
# 25                        Urbanes Gärtnern in Stuttgart  (1, 0.54997414)
# 26    Doch Nutzgärten haben in vielen Städten eine l...  (1, 0.54997414)
# 27            Weitere Gärten in Stuttgart sind geplant.  (1, 0.54997414)
# 28    © Stadt Stuttgart\n \n In den letzten Jahren s...  (1, 0.38348243)
# 31    Berlin stehen die Tafeln in der Rubrik ,,Ökolo...   (1, 0.5499999)
# 38    FDT FlachdachTechnologie GmbH & Co. KG I Eisen...   (1, 0.5657815)
# 39    Die Erfahrungen mit dem Grünen Zimmer werden a...  (1, 0.54997414)
# 49    Der Klimaatlas ist damit eine wichtige Planung...  (1, 0.54997396)
# 64    Stuttgart, Berlin und Chicago besitzen in dies...  (1, 0.54997414)
# 85    Berlin-Tage mit Wärmebelastung, Digitaler Umwe...  (1, 0.52510685)
# 86                                            Stuttgart  (1, 0.54997414)
# 97    8 I 68199 Mannheim I Tel 06 21-85 04-0 I www.f...  (1, 0.69994664)
# 131   11\n | www.taspogartendesign.de |\n \n
# Projek...  (1, 0.36702755)
# 142   2. Kongress ,,Grün in der Stadt", Essen\n \n 1...  (1, 0.33791274)
# 209   8 I 68199 Mannheim I Tel 06 21-85 04-0 I www.f...  (1, 0.69996315)
# 215   Auf Einladung von BGL-Präsident August Forster...  (1, 0.36682883)
# 232   FlachdachTechnologie GmbH & Co. KG I Eisenbahn...   (1, 0.5655252)
# 270                               KG 70499 Stuttgart\n    (1, 0.5499742)
# 279   Zuletzt ist der Professor für Biosystemtechnik...   (1, 0.5499833)
# 312   , 70795 Moshav Kidron, Israel\n \n www.zinco-g...  (1, 0.52518445)
# 340                                     Stuttgart\n \n   (1, 0.54997414)
# 383   Eine Pilotstudie aus Stuttgart sät Zweifel an ...  (1, 0.54997414)
# 417   Bundeskongress in Essen über Maßnahmen und Emp...  (1, 0.48474422)
# 438     Stuttgart hat eine lange Fördertradition.\n \n    (1, 0.5499741)
# 442                                            Essen\n    (1, 0.5499591)
# 452   Diese Klassifizierung erfolgte aufgrund der Ka...   (1, 0.5499741)
# 473                       www.aquatechnik.com l Halle 3         (1, 0.7)
# 478   Einen Werkbericht zur Verwendung von Naturstei...   (1, 0.5499833)
# 491                              . Stuttgart, S. 97­103  (1, 0.54997414)
# ...                                                 ...              ...
# 1103  D 65929 Frankfurt a. Main\n \n www.immo-herbst...  (1, 0.52499974)
# 1105  D 65366 Geisenheim\n \n www.tensio.de\n \n D 6...  (1, 0.54999995)
# 1106  D 70195 Stuttgart\n \n www.wus-architektur.de\...   (1, 0.6999931)
# 1113                 68199 Mannheim D 70439 Stuttgart D   (1, 0.6999553)
# 1114                                 70499 Stuttgart\n    (1, 0.5499741)
# 1116  Pu Tuo District, Shanghai\n \n www.ddb-dachbeg...       (1, 0.775)
# 1120  Viernheim\n \n www.novihum.de www.aco-hochbau....      (1, 0.8875)
# 1127  45133 Essen D 66119 Saarbrücken D 70567 Stuttg...   (1, 0.6450153)
# 1136  INLA Institut für nachhaltige Landschaftsarchi...  (1, 0.36667916)
# 1137  D 65368 Geisenheim am Rhein www.hs-geisenheim....   (1, 0.5746473)
# 1138  www.xeroflor.com www.xeroflor.de www.isatis.de...    (1, 0.633852)
# 1139  D 13053 Berlin\n \n Prof. Dr. Karl-Heinz-Strau...   (1, 0.3675466)
# 1142                        45133 Essen D 49393 Lohne D   (1, 0.5499596)
# 1146  WUS-Architektur WasserUmweltStadt-Architektur\...  (1, 0.54997414)
# 1147           Visioverdis\n \n D 70599 Stuttgart\n \n   (1, 0.54997414)
# 1152      50996 Köln\n \n www.bussmann-feckler.de\n \n   (1, 0.37466538)
# 1154  D 31812 Bad Pyrmont\n \n www.gruendachexperte-...  (1, 0.69997287)
# 1161  Stowarzyszenie DAFA\n \n PL 45-131\n \n Biotop...  (1, 0.36666653)
# 1162  D\n \n Prometheus communication group\n \n D\n...   (1, 0.6080961)
# 1163                                    Stuttgart\n \n    (1, 0.5499741)
# 1191  www.arup.com/campaigns/cities_alive/rethinking...   (1, 0.6999999)
# 1310  Zahlreiche Beispiele wie die üppigen Pflanzent...   (1, 0.5499742)
# 1314  Im Pommerfeld 2 56630 Kretz / Andernach fon +4...   (1, 0.5499999)
# 1315  +49 681-9880570 | info@fbb.de\n \n 134\n \n ww...  (1, 0.47649765)
# 1331  Schönle 51 Optigrün international AG 10 Landsc...   (1, 0.5499744)
# 1340  Architects Bernardgasse 21 A - 1070 Vienna, Te...   (1, 0.6999952)
# 1348  Babul Asociacion de Infrastructura Verde de Ch...  (1, 0.69999486)
# 1352  KG Korntaler Landstraße 63 D - 70499 Stuttgart...   (1, 0.6999931)
# 1357  Deutsche Gesellschaft für Nachhaltiges Bauen ­...   (1, 0.6999924)
# 1358  +43-699-19744304 bernhard.scharf@green4cities....  (1, 0.73638856)
#
# [156 rows x 2 columns]

# %% [markdown]
# It looks like Topic 1 does catch a good number of adresses which might be less relevant than other in-text mentions.
